# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'D:\Intellipaat\Live Classes\ML\Project - Customer Churn\customer_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#Extract the 5th column and store it in ‘customer_5’
customer_5 = data.iloc[:,4:5]
customer_5
# Out:
#      Dependents
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
# ...         ...
# 7038        Yes
# 7039        Yes
# 7040        Yes
# 7041         No
# 7042         No
#
# [7043 rows x 1 columns]

# %%
#Extract the 15th column and store it in ‘customer_15’
customer_15 = data.iloc[:,14:15]
customer_15
# Out:
#      StreamingMovies
# 0                 No
# 1                 No
# 2                 No
# 3                 No
# 4                 No
# ...              ...
# 7038             Yes
# 7039             Yes
# 7040              No
# 7041              No
# 7042             Yes
#
# [7043 rows x 1 columns]

# %%
#Extract all the male senior citizens whose payment method is electronic check and store the result in ‘senior_male_electronic’
senior_male_electronic = data[(data['gender']=='Male') & (data['PaymentMethod']=='Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 14    5129-JLPIS   Male              0      No         No      25
# 20    8779-QRDMV   Male              1      No         No       1
# 26    6467-CHFZW   Male              0     Yes        Yes      47
# 27    8665-UTDHZ   Male              0     Yes        Yes       1
# 36    6047-YHPVI   Male              0      No         No       5
# ...          ...    ...            ...     ...        ...     ...
# 7014  9053-EJUNL   Male              0      No         No      41
# 7020  9837-FWLCH   Male              0     Yes        Yes      12
# 7021  1699-HPSBG   Male              0      No         No      12
# 7022  7203-OYKCT   Male              0      No         No      72
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 14            Yes                No     Fiber optic                  Yes  ...
# ...

# %%
#Extract all those customers whose tenure is greater than 70 months or their monthly charges is more than $100 
#and store the result in ‘customer_total_tenure’
customer_total_tenure = data[(data['tenure']>70) & (data['MonthlyCharges']>100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 17    9959-WOFKT    Male              0      No        Yes      71
# 59    5954-BDFSG  Female              0      No         No      72
# 94    9848-JQJTX    Male              0      No         No      72
# 106   6728-DKUCO  Female              0     Yes        Yes      72
# 193   9680-NIAUV  Female              0     Yes        Yes      72
# ...          ...     ...            ...     ...        ...     ...
# 6859  3508-CFVZL  Female              0      No         No      71
# 6934  6257-DTAYD    Male              0     Yes         No      71
# 6992  0218-QNVAS    Male              0     Yes        Yes      71
# 7022  7203-OYKCT    Male              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 17            Yes           Yes     Fiber optic            Yes  ...
# ...

# %%
#Extract all the customers whose contract is of two years, payment method is mailed check 
#and the value of churn is ‘Yes’ and store the result in ‘two_mail_yes’
two_mail_yes = data[(data['Contract']=='Two year') & (data['PaymentMethod']=='Mailed check') & (data['Churn']=='Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
#Extract 333 random records from the customer_churndataframe and store the result in ‘customer_333’
customer_333 = data.sample(333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6579  3938-YFPXD    Male              0      No         No      72
# 41    9489-DEDVP  Female              0     Yes        Yes      70
# 5     9305-CDSKC  Female              0      No         No       8
# 6503  7781-EWARA    Male              0     Yes        Yes      70
# 3496  5201-FRKKS    Male              0      No         No      25
# ...          ...     ...            ...     ...        ...     ...
# 890   5898-IGSLP    Male              0     Yes        Yes      31
# 2230  5242-UOWHD    Male              0     Yes        Yes      45
# 6855  8738-JOKAR  Female              0      No         No      42
# 3257  5482-VXSXJ    Male              0      No         No      22
# 3536  2254-DLXRI  Female              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 6579          Yes               Yes             DSL                  Yes  ...
# ...

# %%
#Get the count of different levels from the ‘Churn’ column
data['Churn'].value_counts() #use value_counts(normalize=True) for knowing this info in %
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %% [raw]
# 2A. Build a bar-plot for the ’InternetService’ column:
#     a. Set x-axis label to ‘Categories of Internet Service’
#     b. Set y-axis label to ‘Count of Categories’
#     c. Set the title of plot to be ‘Distribution of Internet Service’
#     d. Set the color of the bars to be ‘orange

# %%
data['InternetService'].value_counts().plot(kind='bar',color="orange")
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('Distribution of Internet Service')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [raw]
# 2B. Build a histogram for the ‘tenure’ column:
#     a. Set the number of bins to be 30
#     b. Set the color of the bins to be ‘green’
#     c. Assign the title ‘Distribution of tenure'

# %%
data['tenure'].plot(kind='hist',color="green", bins=30)
plt.title('Distribution of tenure')
# Out:
# Text(0.5, 1.0, 'Distribution of tenure')

# %% [raw]
# 2C. Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map ‘MonthlyCharges’ to the y-axis and ‘tenure’ to the ‘x-           axis’:
#     a. Assign the points a color of ‘brown’
#     b. Set the x-axis label to ‘Tenure of customer’
#     c. Set the y-axis label to ‘Monthly Charges of customer’
#     d. Set the title to ‘Tenure vs Monthly Charges’
#     e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the y-axis &
#     f. ‘Contract’ on the x-axis.

# %%
x=data['tenure']
y=data['MonthlyCharges']
plt.scatter(x,y,color='green')
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
plt.show()

# %%
sns.boxplot(x='Contract', y='tenure', data=data)
# Out:
# <Axes: xlabel='Contract', ylabel='tenure'>

# %%
len(data)-len(data.drop_duplicates())
# Out:
# 0

# %%
data.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
data.drop(columns=['customerID'], inplace=True)

# %%
datacol = data.columns

# %%
for i in data.columns:
    if(data[i].dtype=='object'):
        print(i," ",data[i].unique())
# Out:
# gender   ['Female' 'Male']
# Partner   ['Yes' 'No']
# Dependents   ['No' 'Yes']
# PhoneService   ['No' 'Yes']
# MultipleLines   ['No phone service' 'No' 'Yes']
# InternetService   ['DSL' 'Fiber optic' 'No']
# OnlineSecurity   ['No' 'Yes' 'No internet service']
# OnlineBackup   ['Yes' 'No' 'No internet service']
# DeviceProtection   ['No' 'Yes' 'No internet service']
# TechSupport   ['No' 'Yes' 'No internet service']
# StreamingTV   ['No' 'Yes' 'No internet service']
# StreamingMovies   ['No' 'Yes' 'No internet service']
# Contract   ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling   ['Yes' 'No']
# PaymentMethod   ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn   ['No' 'Yes']

# %%
data['TotalCharges']=pd.to_numeric(data['TotalCharges'], errors='coerce')

# %%
len(data)-len(data.drop_duplicates())
# Out:
# 22

# %%
data.isna().sum()
# Out:
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
for i in data.columns:
    if(data[i].dtype=='object'):
        print(i," ",data[i].unique())
# Out:
# gender   ['Female' 'Male']
# Partner   ['Yes' 'No']
# Dependents   ['No' 'Yes']
# PhoneService   ['No' 'Yes']
# MultipleLines   ['No phone service' 'No' 'Yes']
# InternetService   ['DSL' 'Fiber optic' 'No']
# OnlineSecurity   ['No' 'Yes' 'No internet service']
# OnlineBackup   ['Yes' 'No' 'No internet service']
# DeviceProtection   ['No' 'Yes' 'No internet service']
# TechSupport   ['No' 'Yes' 'No internet service']
# StreamingTV   ['No' 'Yes' 'No internet service']
# StreamingMovies   ['No' 'Yes' 'No internet service']
# Contract   ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling   ['Yes' 'No']
# PaymentMethod   ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# Churn   ['No' 'Yes']

# %%
data['Partner'] = data['Partner'].map({'Yes': 1, 'No': 0})
data['Dependents'] = data['Dependents'].map({'Yes': 1, 'No': 0})
data['MultipleLines']=data['MultipleLines'].map({'No phone service':0, 'No': 1, "Yes": 2})
data['InternetService']=data['InternetService'].map({'DSL':0, 'Fiber optic':1, 'No':2})
data['OnlineSecurity']=data['OnlineSecurity'].map({'Yes':1, 'No':0, 'No internet service':2})
data['OnlineBackup']=data['OnlineBackup'].map({'Yes':1, 'No':0, 'No internet service':2})
data['DeviceProtection']=data['DeviceProtection'].map({'Yes':1, 'No':0, 'No internet service':2})
data['TechSupport']=data['TechSupport'].map({'Yes':1, 'No':0, 'No internet service':2})
data['StreamingTV']=data['StreamingTV'].map({'Yes':1, 'No':0, 'No internet service':2})
data['StreamingMovies']=data['StreamingMovies'].map({'Yes':1, 'No':0, 'No internet service':2})
data['Contract']=data['Contract'].map({'Month-to-month':0, 'One year':1, 'Two year':2})
data['PaperlessBilling']=data['PaperlessBilling'].map({'Yes':1, 'No':0})
data['PaymentMethod']=data['PaymentMethod'].map({'Electronic check':1, 'Mailed check':0, 'Bank transfer (automatic)':2, 'Credit card (automatic)':3})
data['gender'] = data['gender'].map({'Female': 1, 'Male': 0})
data['PhoneService'] = data['PhoneService'].map({'Yes': 1, 'No': 0})
data['Churn']=data['Churn'].map({'Yes':1, 'No':0})

# %%
#x=data.iloc[:,:-1]
#y=data.iloc[:,-1]

x=data['tenure']
y=data['MonthlyCharges']

# %%
x=x.values.reshape(-1, 1)
#this was very important step as we were passing only single independent variable (IMPORTANT)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=20)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
# Out:
# 54.68628611011213

# %%
print(regressor.coef_)
# Out:
# [0.31223461]

# %%
y_pred=regressor.predict(x_test)
y_pred
# Out:
# array([56.24745915, 73.7325972 , 54.99852072, ..., 62.49215131,
#        58.1208668 , 64.05332435])

# %%
y_pred=pd.DataFrame(y_pred,columns=['Predicted'])
y_pred
# Out:
#       Predicted
# 0     56.247459
# 1     73.732597
# 2     54.998521
# 3     74.669301
# 4     73.420363
# ...         ...
# 2105  76.542709
# 2106  68.112374
# 2107  62.492151
# 2108  58.120867
# 2109  64.053324
#
# [2110 rows x 1 columns]

# %%
df_pred=pd.DataFrame(columns=['Actual', 'Pred'])
df_pred['Actual'] = y_test.reset_index()['MonthlyCharges']
df_pred['Pred'] = y_pred.reset_index()['Predicted']
df_pred
# Out:
#       Actual       Pred
# 0      80.10  56.247459
# 1     111.60  73.732597
# 2      70.65  54.998521
# 3      99.15  74.669301
# 4      60.80  73.420363
# ...      ...        ...
# 2105  114.95  76.542709
# 2106   25.10  68.112374
# 2107   70.95  62.492151
# 2108   89.70  58.120867
# 2109   70.25  64.053324
#
# [2110 rows x 2 columns]

# %%
df_pred['error'] = df_pred.Actual -df_pred.Pred
df_pred
# Out:
#       Actual       Pred      error
# 0      80.10  56.247459  23.852541
# 1     111.60  73.732597  37.867403
# 2      70.65  54.998521  15.651479
# 3      99.15  74.669301  24.480699
# 4      60.80  73.420363 -12.620363
# ...      ...        ...        ...
# 2105  114.95  76.542709  38.407291
# 2106   25.10  68.112374 -43.012374
# 2107   70.95  62.492151   8.457849
# 2108   89.70  58.120867  31.579133
# 2109   70.25  64.053324   6.196676
#
# [2110 rows x 3 columns]

# %%
from sklearn import metrics
import numpy as np
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 25.307682082401488
# Mean Squared Error: 848.2988110644716
# Root Mean Squared Error: 29.125569712272952

# %% [raw]
# Part 4: Logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=data['MonthlyCharges']
y=data['Churn']

# %%
x=x.values.reshape(-1, 1)
#this was very important step as we were passing only single independent variable (IMPORTANT)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.35,random_state=20)

# %%
from sklearn.linear_model import LogisticRegression
log_regressor = LogisticRegression()
log_regressor.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_regressor.predict(x_test)

# %%
print('Training Accuracy: %d', (log_regressor.score(x_train, y_train)))
# Out:
# Training Accuracy: %d 0.7354485776805252

# %%
print('Testing Accuracy: %d', (log_regressor.score(x_test, y_test)))
# Out:
# Testing Accuracy: %d 0.7319252640129975

# %%
#Confusion matrix for training data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_train, log_regressor.predict(x_train))
print('TRAINING DATA')
print(confusion_matrix)
# Out:
# TRAINING DATA
# [[3361    0]
#  [1209    0]]

# %%
#Confusion matrix for testing data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print('TESTING DATA')
print(confusion_matrix)
# Out:
# TESTING DATA
# [[1802    0]
#  [ 660    0]]

# %%
x=data[["MonthlyCharges", "tenure"]]
y=data['Churn']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=20)

# %%
from sklearn.linear_model import LogisticRegression
log_regressor1 = LogisticRegression()
log_regressor1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_regressor1.predict(x_test)

# %%
print('Training Accuracy: %d', (log_regressor1.score(x_train, y_train)))
# Out:
# Training Accuracy: %d 0.7838222222222222

# %%
print('Testing Accuracy: %d', (log_regressor1.score(x_test, y_test)))
# Out:
# Testing Accuracy: %d 0.783226723525231

# %%
#Confusion matrix for training data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_train, log_regressor1.predict(x_train))
print('TRAINING DATA')
print(confusion_matrix)
# Out:
# TRAINING DATA
# [[3739  382]
#  [ 834  670]]

# %%
#Confusion matrix for testing data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print('TESTING DATA')
print(confusion_matrix)
# Out:
# TESTING DATA
# [[935 107]
#  [198 167]]

# %% [raw]
# PART 5: Decision Tree

# %%
x=data['tenure']
y=data['Churn']

# %%
x=x.values.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, random_state=20)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
clf = tree.DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(x_test)

# %%
print(f'Train score: {metrics.accuracy_score(y_train_pred,y_train)}')
print(f'Test score: {metrics.accuracy_score(y_test_pred,y_test)}')
# Out:
# Train score: 0.7568
# Test score: 0.7469793887704336

# %%
#Confusion matrix for training data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_train, y_train_pred)
print('TRAINING DATA')
print(confusion_matrix)
# Out:
# TRAINING DATA
# [[3772  349]
#  [1019  485]]

# %%
#Confusion matrix for testing data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_test_pred)
print('TESTING DATA')
print(confusion_matrix)
# Out:
# TESTING DATA
# [[950  92]
#  [264 101]]

# %% [raw]
# PART 6: Random Forest

# %%
x=data[["MonthlyCharges", "tenure"]]
y=data['Churn']

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.3, random_state=20)

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(random_state = 45)
rf=rf.fit(x_train,y_train)

# %%
y_train_pred = rf.predict(x_train)
y_test_pred = rf.predict(x_test)

# %%
print(f'Train score: {metrics.accuracy_score(y_train_pred,y_train)}')
print(f'Test score: {metrics.accuracy_score(y_test_pred,y_test)}')
# Out:
# Train score: 0.9788703778951645
# Test score: 0.7398104265402844

# %%
#Confusion matrix for training data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_train, y_train_pred)
print('TRAINING DATA')
print(confusion_matrix)
# Out:
# TRAINING DATA
# [[3561   49]
#  [  55 1257]]

# %%
#Confusion matrix for testing data
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_test_pred)
print('TESTING DATA')
print(confusion_matrix)
# Out:
# TESTING DATA
# [[1302  251]
#  [ 298  259]]
